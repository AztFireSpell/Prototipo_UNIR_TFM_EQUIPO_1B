# %% [markdown]
# # Transformer para secuencias PaySim
#
# La arquitectura corregida agrega embeddings posicionales; sin ellos, la atencion por si sola no distingue adecuadamente la posicion de cada paso.

# %% [markdown]
# ## Protocolo comun de evaluacion
#
# Este notebook usa tres conjuntos separados: **64% entrenamiento, 16% validacion y 20% prueba**. Validacion sirve para seleccionar el umbral y, cuando aplica, detener el entrenamiento. Prueba se usa una sola vez para las metricas finales.
#
# Se reportan las mismas metricas en todos los modelos: ROC-AUC, PR-AUC, precision, recall, F1, TN, FP, FN, TP, tiempo de entrenamiento e inferencia. Tambien se guardan resultados con umbral 0.5 y con el umbral que maximiza F1 en validacion.
#
# > La comparacion con modelos tabulares solo es directa si cada secuencia y cada fila tabular representan el mismo objetivo de prediccion.

# %% [markdown]
# ## 1. Importaciones

# %%
from pathlib import Path
import json, platform, random, time, warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import (average_precision_score, classification_report, confusion_matrix,
 f1_score, precision_recall_curve, precision_score, recall_score, roc_auc_score,
 RocCurveDisplay, PrecisionRecallDisplay)
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
warnings.filterwarnings('ignore')
RANDOM_STATE=42
random.seed(RANDOM_STATE); np.random.seed(RANDOM_STATE); tf.random.set_seed(RANDOM_STATE)
print('Python:',platform.python_version(),'TensorFlow:',tf.__version__,'GPU:',tf.config.list_physical_devices('GPU'))
# Out:
# Python: 3.10.13 TensorFlow: 2.10.0 GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Configuracion y modo de ejecucion

# %%
X_PATH=Path('datos_muestra/X_paysim_secuencias.npy')
Y_PATH=Path('datos_muestra/y_paysim_etiquetas.npy')
TEST_SIZE=.20
VALID_SIZE_FROM_TRAIN=.20
SPLIT_MODE='time'  # requiere que las secuencias esten ordenadas cronologicamente
BATCH_SIZE=512
EPOCHS=50
PATIENCE=7
OUTPUT_DIR=Path('resultados_transformer_paysim')
OUTPUT_DIR.mkdir(exist_ok=True)
MODEL_NAME='Transformer'
MODEL_PATH=OUTPUT_DIR/'mejor_modelo.keras'
LEGACY_H5_PATH=Path('modelo_fraude_transformer.h5')
# 'train': entrena arquitectura corregida; 'keras': carga mejor_modelo.keras; 'legacy_h5': carga tu H5 previo solo para analizarlo
RUN_MODE='train'
assert RUN_MODE in {'train','keras','legacy_h5'}

# %% [markdown]
# ## 3. Carga de tensores

# %%
if not X_PATH.exists() or not Y_PATH.exists(): raise FileNotFoundError('Ajusta X_PATH/Y_PATH')
X=np.load(X_PATH,mmap_mode='r'); y=np.asarray(np.load(Y_PATH)).reshape(-1).astype('int8')
if X.ndim!=3 or len(X)!=len(y): raise ValueError('Se espera X=(muestras,pasos,variables) y un y por muestra')
if not np.isfinite(X).all(): raise ValueError('X contiene NaN o infinito')
seq_length,num_features=X.shape[1:]
print('X:',X.shape,'y:',y.shape,'fraude:',f'{y.mean():.6%}')
# Out:
# X: (6362620, 5, 9) y: (6362620,) fraude: 0.129082%

# %% [markdown]
# ## 4. Particiones

# %%
idx=np.arange(len(y))
if SPLIT_MODE=='random':
    idx_tv,idx_test=train_test_split(idx,test_size=TEST_SIZE,stratify=y,random_state=RANDOM_STATE)
    idx_train,idx_valid=train_test_split(idx_tv,test_size=VALID_SIZE_FROM_TRAIN,stratify=y[idx_tv],random_state=RANDOM_STATE)
else:
    cut=int(len(idx)*(1-TEST_SIZE)); idx_tv,idx_test=idx[:cut],idx[cut:]
    cut2=int(len(idx_tv)*(1-VALID_SIZE_FROM_TRAIN)); idx_train,idx_valid=idx_tv[:cut2],idx_tv[cut2:]
X_train,y_train=np.asarray(X[idx_train]),y[idx_train]
X_valid,y_valid=np.asarray(X[idx_valid]),y[idx_valid]
X_test,y_test=np.asarray(X[idx_test]),y[idx_test]
for n,z in [('train',y_train),('valid',y_valid),('test',y_test)]: print(f'{n}: {len(z):,} | fraudes={int(z.sum()):,} | tasa={z.mean():.6%}')
assert all(np.unique(z).size==2 for z in (y_train,y_valid,y_test))
np.save(OUTPUT_DIR/'indices_train.npy',idx_train); np.save(OUTPUT_DIR/'indices_valid.npy',idx_valid); np.save(OUTPUT_DIR/'indices_test.npy',idx_test)
classes=np.array([0,1]); w=compute_class_weight('balanced',classes=classes,y=y_train); class_weights={0:float(w[0]),1:float(w[1])}
print('Pesos:',class_weights)
# Out:
# train: 4,072,076 | fraudes=5,272 | tasa=0.129467%
# valid: 1,018,020 | fraudes=1,294 | tasa=0.127109%
# test: 1,272,524 | fraudes=1,647 | tasa=0.129428%
# Pesos: {0: 0.5006481748321286, 1: 386.198406676783}

# %% [markdown]
# ## 5. Arquitectura

# %%
class AddPositionEmbedding(layers.Layer):
    def build(self,input_shape):
        self.pos=self.add_weight(name='position_embedding',shape=(input_shape[1],input_shape[2]),initializer='random_normal')
    def call(self,x): return x+self.pos

def transformer_block(x,head_size=32,num_heads=4,ff_dim=64,dropout=.2):
    a=layers.MultiHeadAttention(key_dim=head_size,num_heads=num_heads,dropout=dropout)(x,x)
    x=layers.LayerNormalization(epsilon=1e-6)(x+layers.Dropout(dropout)(a))
    f=layers.Dense(ff_dim,activation='gelu')(x); f=layers.Dropout(dropout)(f); f=layers.Dense(x.shape[-1])(f)
    return layers.LayerNormalization(epsilon=1e-6)(x+f)

def build_model(seq_length,num_features):
    inputs=layers.Input((seq_length,num_features)); x=AddPositionEmbedding()(inputs)
    x=transformer_block(x); x=transformer_block(x)
    x=layers.GlobalAveragePooling1D()(x); x=layers.Dropout(.3)(x); x=layers.Dense(32,activation='relu')(x)
    outputs=layers.Dense(1,activation='sigmoid')(x)
    m=tf.keras.Model(inputs,outputs,name='Transformer_fraude')
    m.compile(tf.keras.optimizers.Adam(1e-3),'binary_crossentropy',metrics=['accuracy',
      tf.keras.metrics.Precision(name='precision'),tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(curve='ROC',name='auc_roc'),tf.keras.metrics.AUC(curve='PR',name='auc_pr')])
    return m

# %% [markdown]
# ## 6. Entrenar o cargar modelo

# %%
callbacks=[EarlyStopping(monitor='val_auc_pr',mode='max',patience=PATIENCE,restore_best_weights=True,verbose=1),
 ModelCheckpoint(MODEL_PATH,monitor='val_auc_pr',mode='max',save_best_only=True,verbose=1),
 ReduceLROnPlateau(monitor='val_auc_pr',mode='max',factor=.5,patience=3,min_lr=1e-6,verbose=1)]
training_seconds=None; history=None
if RUN_MODE=='train':
    model=build_model(seq_length,num_features)
    start=time.perf_counter(); history=model.fit(X_train,y_train,validation_data=(X_valid,y_valid),epochs=EPOCHS,
      batch_size=BATCH_SIZE,class_weight=class_weights,callbacks=callbacks,shuffle=False,verbose=1); training_seconds=time.perf_counter()-start
    model=tf.keras.models.load_model(MODEL_PATH,compile=False)
elif RUN_MODE=='keras':
    model=tf.keras.models.load_model(MODEL_PATH,compile=False)
else:
    if not LEGACY_H5_PATH.exists(): raise FileNotFoundError(f'No se encontro {LEGACY_H5_PATH}')
    model=tf.keras.models.load_model(LEGACY_H5_PATH,compile=False)
model.summary()
if history is not None:
    pd.DataFrame(history.history).to_csv(OUTPUT_DIR/'historial.csv',index_label='epoch')
# Out:
# Epoch 1/50
# 7954/7954 [==============================] - ETA: 0s - loss: 0.1339 - accuracy: 0.9450 - precision: 0.0222 - recall: 0.9634 - auc_roc: 0.9871 - auc_pr: 0.1634
# Epoch 1: val_auc_pr improved from -inf to 0.50381, saving model to resultados_transformer_paysim\mejor_modelo.keras
# 7954/7954 [==============================] - 245s 30ms/step - loss: 0.1339 - accuracy: 0.9450 - precision: 0.0222 - recall: 0.9634 - auc_roc: 0.9871 - auc_pr: 0.1634 - val_loss: 0.0176 - val_accuracy: 0.9956 - val_precision: 0.2085 - val_recall: 0.8709 - val_auc_roc: 0.9957 - val_auc_pr: 0.5038 - lr: 0.0010
# Epoch 2/50
# 7954/7954 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9725 - precision: 0.0441 - recall: 0.9791 - auc_roc: 0.9929 - auc_pr: 0.2511
# Epoch 2: val_auc_pr improved from 0.50381 to 0.74639, saving model to resultados_transformer_paysim\mejor_modelo.keras
# 7954/7954 [==============================] - 231s 29ms/step - loss: 0.0830 - accuracy: 0.9725 - precision: 0.0441 - recall: 0.9791 - auc_roc: 0.9929 - auc_pr: 0.2511 - val_loss: 0.0111 - val_accuracy: 0.9987 - val_precision: 0.4840 - val_recall: 0.8856 - val_auc_roc: 0.9971 - val_auc_pr: 0.7464 - lr: 0.0010
# Epoch 3/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0723 - accuracy: 0.9770 - precision: 0.0525 - recall: 0.9808 - auc_roc: 0.9943 - auc_pr: 0.2586
# Epoch 3: val_auc_pr did not improve from 0.74639
# 7954/7954 [==============================] - 199s 25ms/step - loss: 0.0723 - accuracy: 0.9770 - precision: 0.0525 - recall: 0.9808 - auc_roc: 0.9943 - auc_pr: 0.2586 - val_loss: 0.0199 - val_accuracy: 0.9943 - val_precision: 0.1730 - val_recall: 0.9274 - val_auc_roc: 0.9972 - val_auc_pr: 0.5435 - lr: 0.0010
# Epoch 4/50
# 7954/7954 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9788 - precision: 0.0569 - recall: 0.9865 - auc_roc: 0.9946 - auc_pr: 0.2757
# Epoch 4: val_auc_pr improved from 0.74639 to 0.81400, saving model to resultados_transformer_paysim\mejor_modelo.keras
# 7954/7954 [==============================] - 204s 26ms/step - loss: 0.0668 - accuracy: 0.9788 - precision: 0.0569 - recall: 0.9865 - auc_roc: 0.9946 - auc_pr: 0.2757 - val_loss: 0.0082 - val_accuracy: 0.9988 - val_precision: 0.5263 - val_recall: 0.8879 - val_auc_roc: 0.9980 - val_auc_pr: 0.8140 - lr: 0.0010
# Epoch 5/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0650 - accuracy: 0.9789 - precision: 0.0570 - recall: 0.9848 - auc_roc: 0.9949 - auc_pr: 0.3172
# Epoch 5: val_auc_pr did not improve from 0.81400
# 7954/7954 [==============================] - 210s 26ms/step - loss: 0.0650 - accuracy: 0.9789 - precision: 0.0570 - recall: 0.9848 - auc_roc: 0.9949 - auc_pr: 0.3172 - val_loss: 0.0752 - val_accuracy: 0.9696 - val_precision: 0.0400 - val_recall: 0.9938 - val_auc_roc: 0.9960 - val_auc_pr: 0.3293 - lr: 0.0010
# Epoch 6/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0649 - accuracy: 0.9787 - precision: 0.0566 - recall: 0.9848 - auc_roc: 0.9952 - auc_pr: 0.3455
# Epoch 6: val_auc_pr did not improve from 0.81400
# 7954/7954 [==============================] - 237s 30ms/step - loss: 0.0649 - accuracy: 0.9787 - precision: 0.0566 - recall: 0.9848 - auc_roc: 0.9952 - auc_pr: 0.3455 - val_loss: 0.0488 - val_accuracy: 0.9693 - val_precision: 0.0395 - val_recall: 0.9915 - val_auc_roc: 0.9965 - val_auc_pr: 0.7742 - lr: 0.0010
# Epoch 7/50
# 7953/7954 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9783 - precision: 0.0554 - recall: 0.9844 - auc_roc: 0.9949 - auc_pr: 0.3212
# Epoch 7: val_auc_pr did not improve from 0.81400
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 7954/7954 [==============================] - 249s 31ms/step - loss: 0.0664 - accuracy: 0.9783 - precision: 0.0554 - recall: 0.9844 - auc_roc: 0.9949 - auc_pr: 0.3212 - val_loss: 0.0146 - val_accuracy: 0.9964 - val_precision: 0.2541 - val_recall: 0.9312 - val_auc_roc: 0.9976 - val_auc_pr: 0.6870 - lr: 0.0010
# Epoch 8/50
# 7954/7954 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9877 - precision: 0.0941 - recall: 0.9888 - auc_roc: 0.9958 - auc_pr: 0.4078
# Epoch 8: val_auc_pr did not improve from 0.81400
# 7954/7954 [==============================] - 228s 29ms/step - loss: 0.0474 - accuracy: 0.9877 - precision: 0.0941 - recall: 0.9888 - auc_roc: 0.9958 - auc_pr: 0.4078 - val_loss: 0.0128 - val_accuracy: 0.9977 - val_precision: 0.3503 - val_recall: 0.9706 - val_auc_roc: 0.9984 - val_auc_pr: 0.7431 - lr: 5.0000e-04
# Epoch 9/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9884 - precision: 0.0998 - recall: 0.9896 - auc_roc: 0.9963 - auc_pr: 0.4748
# Epoch 9: val_auc_pr did not improve from 0.81400
# 7954/7954 [==============================] - 225s 28ms/step - loss: 0.0443 - accuracy: 0.9884 - precision: 0.0998 - recall: 0.9896 - auc_roc: 0.9963 - auc_pr: 0.4748 - val_loss: 0.0084 - val_accuracy: 0.9987 - val_precision: 0.4872 - val_recall: 0.9560 - val_auc_roc: 0.9981 - val_auc_pr: 0.7893 - lr: 5.0000e-04
# Epoch 10/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9883 - precision: 0.0988 - recall: 0.9907 - auc_roc: 0.9966 - auc_pr: 0.4154
# Epoch 10: val_auc_pr improved from 0.81400 to 0.85860, saving model to resultados_transformer_paysim\mejor_modelo.keras
# 7954/7954 [==============================] - 239s 30ms/step - loss: 0.0439 - accuracy: 0.9883 - precision: 0.0988 - recall: 0.9907 - auc_roc: 0.9966 - auc_pr: 0.4155 - val_loss: 0.0052 - val_accuracy: 0.9993 - val_precision: 0.6986 - val_recall: 0.8385 - val_auc_roc: 0.9980 - val_auc_pr: 0.8586 - lr: 5.0000e-04
# Epoch 11/50
# 7953/7954 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9895 - precision: 0.1094 - recall: 0.9911 - auc_roc: 0.9966 - auc_pr: 0.4521
# Epoch 11: val_auc_pr improved from 0.85860 to 0.86548, saving model to resultados_transformer_paysim\mejor_modelo.keras
# 7954/7954 [==============================] - 235s 30ms/step - loss: 0.0415 - accuracy: 0.9895 - precision: 0.1094 - recall: 0.9911 - auc_roc: 0.9966 - auc_pr: 0.4521 - val_loss: 0.0074 - val_accuracy: 0.9993 - val_precision: 0.6695 - val_recall: 0.9266 - val_auc_roc: 0.9992 - val_auc_pr: 0.8655 - lr: 5.0000e-04
# Epoch 12/50
# 7953/7954 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9883 - precision: 0.0986 - recall: 0.9901 - auc_roc: 0.9964 - auc_pr: 0.4636
# Epoch 12: val_auc_pr improved from 0.86548 to 0.88237, saving model to resultados_transformer_paysim\mejor_modelo.keras
# 7954/7954 [==============================] - 237s 30ms/step - loss: 0.0442 - accuracy: 0.9883 - precision: 0.0985 - recall: 0.9901 - auc_roc: 0.9964 - auc_pr: 0.4636 - val_loss: 0.0186 - val_accuracy: 0.9921 - val_precision: 0.1383 - val_recall: 0.9938 - val_auc_roc: 0.9989 - val_auc_pr: 0.8824 - lr: 5.0000e-04
# Epoch 13/50
# 7954/7954 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9861 - precision: 0.0846 - recall: 0.9913 - auc_roc: 0.9967 - auc_pr: 0.4477
# Epoch 13: val_auc_pr improved from 0.88237 to 0.89371, saving model to resultados_transformer_paysim\mejor_modelo.keras
# 7954/7954 [==============================] - 209s 26ms/step - loss: 0.0443 - accuracy: 0.9861 - precision: 0.0846 - recall: 0.9913 - auc_roc: 0.9967 - auc_pr: 0.4477 - val_loss: 0.0108 - val_accuracy: 0.9954 - val_precision: 0.2154 - val_recall: 0.9892 - val_auc_roc: 0.9988 - val_auc_pr: 0.8937 - lr: 5.0000e-04
# Epoch 14/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9887 - precision: 0.1022 - recall: 0.9907 - auc_roc: 0.9961 - auc_pr: 0.4601
# Epoch 14: val_auc_pr did not improve from 0.89371
# 7954/7954 [==============================] - 241s 30ms/step - loss: 0.0444 - accuracy: 0.9887 - precision: 0.1022 - recall: 0.9907 - auc_roc: 0.9961 - auc_pr: 0.4601 - val_loss: 0.0070 - val_accuracy: 0.9980 - val_precision: 0.3765 - val_recall: 0.9119 - val_auc_roc: 0.9757 - val_auc_pr: 0.7685 - lr: 5.0000e-04
# Epoch 15/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9852 - precision: 0.0798 - recall: 0.9909 - auc_roc: 0.9966 - auc_pr: 0.4327
# Epoch 15: val_auc_pr did not improve from 0.89371
# 7954/7954 [==============================] - 236s 30ms/step - loss: 0.0479 - accuracy: 0.9852 - precision: 0.0798 - recall: 0.9909 - auc_roc: 0.9966 - auc_pr: 0.4327 - val_loss: 0.0149 - val_accuracy: 0.9967 - val_precision: 0.2783 - val_recall: 0.9830 - val_auc_roc: 0.9989 - val_auc_pr: 0.8635 - lr: 5.0000e-04
# Epoch 16/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0396 - accuracy: 0.9893 - precision: 0.1077 - recall: 0.9920 - auc_roc: 0.9967 - auc_pr: 0.4669
# Epoch 16: val_auc_pr did not improve from 0.89371
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 7954/7954 [==============================] - 266s 33ms/step - loss: 0.0395 - accuracy: 0.9893 - precision: 0.1077 - recall: 0.9920 - auc_roc: 0.9967 - auc_pr: 0.4669 - val_loss: 0.0257 - val_accuracy: 0.9907 - val_precision: 0.1198 - val_recall: 0.9954 - val_auc_roc: 0.9987 - val_auc_pr: 0.6694 - lr: 5.0000e-04
# Epoch 17/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0362 - accuracy: 0.9923 - precision: 0.1430 - recall: 0.9918 - auc_roc: 0.9964 - auc_pr: 0.5370
# Epoch 17: val_auc_pr improved from 0.89371 to 0.93537, saving model to resultados_transformer_paysim\mejor_modelo.keras
# 7954/7954 [==============================] - 229s 29ms/step - loss: 0.0362 - accuracy: 0.9923 - precision: 0.1429 - recall: 0.9918 - auc_roc: 0.9964 - auc_pr: 0.5370 - val_loss: 0.0216 - val_accuracy: 0.9907 - val_precision: 0.1202 - val_recall: 0.9961 - val_auc_roc: 0.9990 - val_auc_pr: 0.9354 - lr: 2.5000e-04
# Epoch 18/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9935 - precision: 0.1658 - recall: 0.9922 - auc_roc: 0.9971 - auc_pr: 0.5527
# Epoch 18: val_auc_pr did not improve from 0.93537
# 7954/7954 [==============================] - 236s 30ms/step - loss: 0.0322 - accuracy: 0.9935 - precision: 0.1658 - recall: 0.9922 - auc_roc: 0.9971 - auc_pr: 0.5528 - val_loss: 0.0066 - val_accuracy: 0.9988 - val_precision: 0.5049 - val_recall: 0.9907 - val_auc_roc: 0.9991 - val_auc_pr: 0.9061 - lr: 2.5000e-04
# Epoch 19/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9939 - precision: 0.1733 - recall: 0.9928 - auc_roc: 0.9978 - auc_pr: 0.5782
# Epoch 19: val_auc_pr did not improve from 0.93537
# 7954/7954 [==============================] - 225s 28ms/step - loss: 0.0304 - accuracy: 0.9939 - precision: 0.1733 - recall: 0.9928 - auc_roc: 0.9978 - auc_pr: 0.5783 - val_loss: 0.0065 - val_accuracy: 0.9992 - val_precision: 0.6252 - val_recall: 0.8547 - val_auc_roc: 0.9990 - val_auc_pr: 0.8902 - lr: 2.5000e-04
# Epoch 20/50
# 7953/7954 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9932 - precision: 0.1594 - recall: 0.9928 - auc_roc: 0.9973 - auc_pr: 0.5932
# Epoch 20: val_auc_pr did not improve from 0.93537
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 7954/7954 [==============================] - 230s 29ms/step - loss: 0.0323 - accuracy: 0.9932 - precision: 0.1594 - recall: 0.9928 - auc_roc: 0.9973 - auc_pr: 0.5932 - val_loss: 0.0098 - val_accuracy: 0.9982 - val_precision: 0.4180 - val_recall: 0.9869 - val_auc_roc: 0.9990 - val_auc_pr: 0.8503 - lr: 2.5000e-04
# Epoch 21/50
# 7954/7954 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9951 - precision: 0.2093 - recall: 0.9928 - auc_roc: 0.9974 - auc_pr: 0.6173
# Epoch 21: val_auc_pr did not improve from 0.93537
# 7954/7954 [==============================] - 225s 28ms/step - loss: 0.0276 - accuracy: 0.9951 - precision: 0.2093 - recall: 0.9928 - auc_roc: 0.9974 - auc_pr: 0.6173 - val_loss: 0.0206 - val_accuracy: 0.9937 - val_precision: 0.1672 - val_recall: 0.9961 - val_auc_roc: 0.9991 - val_auc_pr: 0.9163 - lr: 1.2500e-04
# Epoch 22/50
# 7954/7954 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9963 - precision: 0.2597 - recall: 0.9934 - auc_roc: 0.9974 - auc_pr: 0.6662
# Epoch 22: val_auc_pr did not improve from 0.93537
# 7954/7954 [==============================] - 225s 28ms/step - loss: 0.0260 - accuracy: 0.9963 - precision: 0.2597 - recall: 0.9934 - auc_roc: 0.9974 - auc_pr: 0.6662 - val_loss: 0.0074 - val_accuracy: 0.9992 - val_precision: 0.6018 - val_recall: 0.9938 - val_auc_roc: 0.9992 - val_auc_pr: 0.9313 - lr: 1.2500e-04
# Epoch 23/50
# 7952/7954 [============================>.] - ETA: 0s - loss: 0.0276 - accuracy: 0.9953 - precision: 0.2150 - recall: 0.9926 - auc_roc: 0.9974 - auc_pr: 0.5982
# Epoch 23: val_auc_pr did not improve from 0.93537
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 7954/7954 [==============================] - 246s 31ms/step - loss: 0.0276 - accuracy: 0.9953 - precision: 0.2150 - recall: 0.9926 - auc_roc: 0.9974 - auc_pr: 0.5982 - val_loss: 0.0098 - val_accuracy: 0.9974 - val_precision: 0.3287 - val_recall: 0.9961 - val_auc_roc: 0.9991 - val_auc_pr: 0.8540 - lr: 1.2500e-04
# Epoch 24/50
# 7953/7954 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 0.9964 - precision: 0.2630 - recall: 0.9939 - auc_roc: 0.9975 - auc_pr: 0.6842Restoring model weights from the end of the best epoch: 17.
#
# Epoch 24: val_auc_pr did not improve from 0.93537
# 7954/7954 [==============================] - 223s 28ms/step - loss: 0.0248 - accuracy: 0.9964 - precision: 0.2630 - recall: 0.9939 - auc_roc: 0.9975 - auc_pr: 0.6842 - val_loss: 0.0080 - val_accuracy: 0.9987 - val_precision: 0.4986 - val_recall: 0.9961 - val_auc_roc: 0.9992 - val_auc_pr: 0.9103 - lr: 6.2500e-05
# Epoch 24: early stopping
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 9
#       6     model=build_model(seq_length,num_features)
#       7     start=time.perf_counter(); history=model.fit(X_train,y_train,validation_data=(X_valid,y_valid),epochs=EPOCHS,
#       8       batch_size=BATCH_SIZE,class_weight=class_weights,callbacks=callbacks,shuffle=False,verbose=1); training_seconds=time.perf_counter()-start
# ----> 9     model=tf.keras.models.load_model(MODEL_PATH,compile=False)
#      10 elif RUN_MODE=='keras':
#      11     model=tf.keras.models.load_model(MODEL_PATH,compile=False)
#
# File ~\.conda\envs\tensorflow\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\.conda\envs\tensorflow\lib\site-packages\keras\utils\generic_utils.py:605, in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     603 cls = get_registered_object(class_name, custom_objects, module_objects)
#     604 if cls is None:
# --> 605     raise ValueError(
#     606         f"Unknown {printable_module_name}: {class_name}. "
#     607         "Please ensure this "
#     608         "object is passed to the `custom_objects` argument. See "
#     609         "https://www.tensorflow.org/guide/keras/save_and_serialize"
#     610         "#registering_the_custom_object for details."
#     611     )
#     613 cls_config = config["config"]
#     614 # Check if `cls_config` is a list. If it is a list, return the class and the
#     615 # associated class configs for recursively deserialization. This case will
#     616 # happen on the old version of sequential model (e.g. `keras_version` ==
#     617 # "2.0.6"), which is serialized in a different structure, for example
#     618 # "{'class_name': 'Sequential',
#     619 #   'config': [{'class_name': 'Embedding', 'config': ...}, {}, ...]}".
#
# ValueError: Unknown layer: AddPositionEmbedding. Please ensure this object is passed to the `custom_objects` argument. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %% [markdown]
# ## 7. Probabilidades

# %%
start=time.perf_counter(); proba_valid=model.predict(X_valid,batch_size=BATCH_SIZE,verbose=1).ravel(); proba_test=model.predict(X_test,batch_size=BATCH_SIZE,verbose=1).ravel(); inference_seconds=time.perf_counter()-start
# Out:
# 1989/1989 [==============================] - 20s 9ms/step
# 2486/2486 [==============================] - 24s 10ms/step

# %% [markdown]
# ## 8. Metricas

# %%
def metricas(y_true,proba,threshold):
    pred=(proba>=threshold).astype(int); tn,fp,fn,tp=confusion_matrix(y_true,pred).ravel()
    return {'threshold':float(threshold),'roc_auc':float(roc_auc_score(y_true,proba)),
      'pr_auc':float(average_precision_score(y_true,proba)),
      'precision':float(precision_score(y_true,pred,zero_division=0)),
      'recall':float(recall_score(y_true,pred,zero_division=0)),
      'f1':float(f1_score(y_true,pred,zero_division=0)),
      'tn':int(tn),'fp':int(fp),'fn':int(fn),'tp':int(tp)}
def elegir_umbral(y_true,proba):
    p,r,t=precision_recall_curve(y_true,proba)
    f=2*p[:-1]*r[:-1]/(p[:-1]+r[:-1]+1e-12)
    i=int(np.nanargmax(f)); return float(t[i]),float(f[i])
def sensibilidad(y_true,proba):
    rows=[]
    for u in np.round(np.arange(.05,1,.05),2):
        m=metricas(y_true,proba,u); rows.append(m)
    return pd.DataFrame(rows)

# %%
best_threshold,best_f1_valid=elegir_umbral(y_valid,proba_valid)
baseline=metricas(y_test,proba_test,.5)
tuned=metricas(y_test,proba_test,best_threshold)
comparison=pd.DataFrame([baseline,tuned],index=['umbral_0.5','umbral_validacion'])
display(comparison)
pred_test=(proba_test>=best_threshold).astype(int)
print('Umbral elegido en validacion:',best_threshold,'| F1 validacion:',best_f1_valid)
print(classification_report(y_test,pred_test,digits=4,zero_division=0))
fig,ax=plt.subplots(1,3,figsize=(18,5))
sns.heatmap(confusion_matrix(y_test,pred_test),annot=True,fmt=',d',cmap='Blues',cbar=False,ax=ax[0])
ax[0].set(title=f'Matriz de confusion (t={best_threshold:.4f})',xlabel='Prediccion',ylabel='Real')
RocCurveDisplay.from_predictions(y_test,proba_test,ax=ax[1],name=MODEL_NAME); ax[1].set_title('ROC - prueba')
PrecisionRecallDisplay.from_predictions(y_test,proba_test,ax=ax[2],name=MODEL_NAME); ax[2].set_title('Precision-recall - prueba')
plt.tight_layout(); plt.savefig(OUTPUT_DIR/'evaluacion_final.png',dpi=300,bbox_inches='tight'); plt.show()
# Out:
#                    threshold  roc_auc    pr_auc  precision    recall  \
# umbral_0.5          0.500000  0.99763  0.939658   0.802476  0.905282
# umbral_validacion   0.790429  0.99763  0.939658   0.938305  0.840316
#
#                          f1       tn   fp   fn    tp
# umbral_0.5         0.850785  1270510  367  156  1491
# umbral_validacion  0.886611  1270786   91  263  1384
# Umbral elegido en validacion: 0.7904291749000549 | F1 validacion: 0.88598283612537
#               precision    recall  f1-score   support
#
#            0     0.9998    0.9999    0.9999   1270877
#            1     0.9383    0.8403    0.8866      1647
#
#     accuracy                         0.9997   1272524
#    macro avg     0.9690    0.9201    0.9432   1272524
# weighted avg     0.9997    0.9997    0.9997   1272524

# %% [markdown]
# ## 9. Sensibilidad

# %%
sens=sensibilidad(y_valid,proba_valid)
sens.to_csv(OUTPUT_DIR/'sensibilidad_validacion.csv',index=False)
fig,ax1=plt.subplots(figsize=(11,6))
l1,=ax1.plot(sens.threshold,sens.f1,marker='o',label='F1'); ax1.set(xlabel='Umbral',ylabel='F1')
ax1.axvline(best_threshold,color='black',linestyle=':',label=f'Elegido={best_threshold:.3f}')
ax2=ax1.twinx(); l2,=ax2.plot(sens.threshold,sens.fp,'--s',label='Falsos positivos'); l3,=ax2.plot(sens.threshold,sens.fn,'--^',label='Falsos negativos'); ax2.set_ylabel('Casos')
h1,labs1=ax1.get_legend_handles_labels(); h2,labs2=ax2.get_legend_handles_labels(); ax1.legend(h1+h2,labs1+labs2,loc='best')
plt.title(f'Analisis de sensibilidad - {MODEL_NAME} (validacion)'); fig.tight_layout()
plt.savefig(OUTPUT_DIR/'analisis_sensibilidad.png',dpi=300,bbox_inches='tight'); plt.show()

# %% [markdown]
# ## 10. Exportacion

# %%
results={'model':MODEL_NAME,'data_unit':'secuencia','run_mode':RUN_MODE,'split_mode':SPLIT_MODE,
 'n_train':len(y_train),'n_valid':len(y_valid),'n_test':len(y_test),'sequence_length':int(seq_length),
 'num_features':int(num_features),'training_seconds':training_seconds,'inference_seconds':inference_seconds,
 'metrics_threshold_0_5':baseline,'metrics_threshold_validation':tuned}
json.dump(results,open(OUTPUT_DIR/'metricas.json','w',encoding='utf-8'),ensure_ascii=False,indent=2)
pd.DataFrame({'index_original':idx_test,'y_true':y_test,'probabilidad_fraude':proba_test,'prediccion':pred_test}).to_csv(OUTPUT_DIR/'predicciones_test.csv',index=False)
print('Guardado en',OUTPUT_DIR.resolve())
# Out:
# Guardado en C:\Users\alomi\Documentos\Unir\ProyectoFinal\notebooks_finales\resultados_transformer_paysim
